# %% [markdown]
# <a href="https://colab.research.google.com/github/SamridhiParihar/Machine-Learning-Projects/blob/main/DataScienceChallenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DATA SCIENCE CHALLENGE PROJECT COURSERA

# %%
import pandas as pd
data_descriptions = pd.read_csv('data_descriptions.csv')
pd.set_option('display.max_colwidth', None)
data_descriptions
# Out:
#                  Column_name Column_type Data_type  \
# 0                 AccountAge     Feature   integer
# 1             MonthlyCharges     Feature     float
# 2               TotalCharges     Feature     float
# 3           SubscriptionType     Feature    object
# 4              PaymentMethod     Feature    string
# 5           PaperlessBilling     Feature    string
# 6                ContentType     Feature    string
# 7          MultiDeviceAccess     Feature    string
# 8           DeviceRegistered     Feature    string
# 9        ViewingHoursPerWeek     Feature     float
# 10    AverageViewingDuration     Feature     float
# 11  ContentDownloadsPerMonth     Feature   integer
# 12           GenrePreference     Feature    string
# 13                UserRating     Feature     float
# 14    SupportTicketsPerMonth     Feature   integer
# 15                    Gender     Feature    string
# 16             WatchlistSize     Feature     float
# ...

# %%
columns_to_encode=['SubscriptionType','PaymentMethod','PaperlessBilling','ContentType','MultiDeviceAccess','DeviceRegistered','GenrePreference','Gender','ParentalControl','SubtitlesEnabled']

# %% [markdown]
# ##importing modules required

# %%
import numpy as np
import pandas as pd

# Machine Learning / Classification packages
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


# Visualization Packages
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_df = pd.read_csv("train.csv")
print('train_df Shape:', train_df.shape)
train_df.head()
# Out:
# train_df Shape: (123841, 21)
#    AccountAge  MonthlyCharges  TotalCharges SubscriptionType  \
# 0          20       11.055215    221.104302          Premium
# 1          57        5.175208    294.986882            Basic
# 2          73       12.106657    883.785952            Basic
# 3          32        7.263743    232.439774            Basic
# 4          57       16.953078    966.325422          Premium
#
#       PaymentMethod PaperlessBilling ContentType MultiDeviceAccess  \
# 0      Mailed check               No        Both                No
# 1       Credit card              Yes      Movies                No
# 2      Mailed check              Yes      Movies                No
# 3  Electronic check               No    TV Shows                No
# 4  Electronic check              Yes    TV Shows                No
#
#   DeviceRegistered  ViewingHoursPerWeek  ...  ContentDownloadsPerMonth  \
# 0           Mobile            36.758104  ...                      10.0
# ...

# %%
print(train_df.shape)
# Out:
# (123841, 21)

# %%
train_df.tail()
# Out:
#         AccountAge  MonthlyCharges  TotalCharges SubscriptionType  \
# 123836         113       17.185820   1941.997639          Premium
# 123837          57       10.192039    580.946205            Basic
# 123838         109       19.574475   2133.617766            Basic
# 123839          98       10.780798   1056.518243          Premium
# 123840          29       13.384635    388.154412            Basic
#
#            PaymentMethod PaperlessBilling ContentType MultiDeviceAccess  \
# 123836       Credit card              Yes    TV Shows               Yes
# 123837      Mailed check               No        Both                No
# 123838     Bank transfer              Yes      Movies               Yes
# 123839       Credit card               No    TV Shows               Yes
# 123840  Electronic check               No      Movies               Yes
#
#        DeviceRegistered  ViewingHoursPerWeek  ...  ContentDownloadsPerMonth  \
# ...

# %%
test_df = pd.read_csv("test.csv")
print('test_df Shape:', test_df.shape)
test_df.head()
# Out:
# test_df Shape: (104480, 20)
#    AccountAge  MonthlyCharges  TotalCharges SubscriptionType  \
# 0          38       17.869374    679.036195          Premium
# 1          77        9.912854    763.289768            Basic
# 2           5       15.019011     75.095057         Standard
# 3          88       15.357406   1351.451692         Standard
# 4          91       12.406033   1128.949004         Standard
#
#       PaymentMethod PaperlessBilling ContentType MultiDeviceAccess  \
# 0      Mailed check               No    TV Shows                No
# 1  Electronic check              Yes    TV Shows                No
# 2     Bank transfer               No    TV Shows               Yes
# 3  Electronic check               No        Both               Yes
# 4       Credit card              Yes    TV Shows               Yes
#
#   DeviceRegistered  ViewingHoursPerWeek  AverageViewingDuration  \
# 0               TV            29.126308              122.274031
# ...

# %% [markdown]
# #label_encoding

# %%
from sklearn.preprocessing import LabelEncoder
#load the label encoder function
label_encoder=LabelEncoder() # store this function into variable as label_encoder

# %%
train_df['SubscriptionType'].value_counts()
# Out:
# 2    41780
# 0    41252
# 1    40809
# Name: SubscriptionType, dtype: int64

# %%
labels=label_encoder.fit_transform(train_df.SubscriptionType)

# %%
train_df['SubscriptionType']=labels

# %%
train_df['SubscriptionType'].value_counts()
# Out:
# 2    41780
# 0    41252
# 1    40809
# Name: SubscriptionType, dtype: int64

# %% [markdown]
# therefore for:
# standarad:2
# basic:0
# premium: 1

# %%
columns_to_encode=['SubscriptionType','PaymentMethod','PaperlessBilling','ContentType','MultiDeviceAccess','DeviceRegistered','GenrePreference','Gender','ParentalControl','SubtitlesEnabled']

# %%
#label encoding to all the columns
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer(
    transformers=[
        ('label_encoder',label_encoder, columns_to_encode)
    ],
    remainder='passthrough'  # Leave the remaining columns unchanged
)

# %%
# Extract the specified columns from the dataframe
columns_data = train_df[columns_to_encode]
# Apply label encoding to the specified columns
encoded_data = columns_data.apply(lambda x:label_encoder.fit_transform(x))
# Concatenate the encoded columns with the remaining columns
encoded_df = pd.concat([encoded_data, train_df.drop(columns_to_encode, axis=1)], axis=1)

# %%
columns_data = test_df[columns_to_encode]
encoded_data_test= columns_data.apply(lambda x:label_encoder.fit_transform(x))
encoded_df_test = pd.concat([encoded_data_test, test_df.drop(columns_to_encode, axis=1)], axis=1)

# %%
test_df=encoded_df_test
test_df.head()
# Out:
#    SubscriptionType  PaymentMethod  PaperlessBilling  ContentType  \
# 0                 1              3                 0            2
# 1                 0              2                 1            2
# 2                 2              0                 0            2
# 3                 2              2                 0            0
# 4                 2              1                 1            2
#
#    MultiDeviceAccess  DeviceRegistered  GenrePreference  Gender  \
# 0                  0                 2                1       1
# 1                  0                 2                0       0
# 2                  1                 0                4       0
# 3                  1                 3                1       0
# 4                  1                 3                2       0
#
#    ParentalControl  SubtitlesEnabled  AccountAge  MonthlyCharges  \
# 0                0                 0          38       17.869374
# ...

# %%
encoded_df.head()
# Out:
#    SubscriptionType  PaymentMethod  PaperlessBilling  ContentType  \
# 0                 1              3                 0            0
# 1                 0              1                 1            1
# 2                 0              3                 1            1
# 3                 0              2                 0            2
# 4                 1              2                 1            2
#
#    MultiDeviceAccess  DeviceRegistered  GenrePreference  Gender  \
# 0                  0                 1                4       1
# 1                  0                 3                0       1
# 2                  0                 0                3       1
# 3                  0                 3                2       1
# 4                  0                 2                1       0
#
#    ParentalControl  SubtitlesEnabled  ...  MonthlyCharges  TotalCharges  \
# 0                0                 0  ...       11.055215    221.104302
# ...

# %%
train_df=encoded_df
train_df.head()
# Out:
#    SubscriptionType  PaymentMethod  PaperlessBilling  ContentType  \
# 0                 1              3                 0            0
# 1                 0              1                 1            1
# 2                 0              3                 1            1
# 3                 0              2                 0            2
# 4                 1              2                 1            2
#
#    MultiDeviceAccess  DeviceRegistered  GenrePreference  Gender  \
# 0                  0                 1                4       1
# 1                  0                 3                0       1
# 2                  0                 0                3       1
# 3                  0                 3                2       1
# 4                  0                 2                1       0
#
#    ParentalControl  SubtitlesEnabled  ...  MonthlyCharges  TotalCharges  \
# 0                0                 0  ...       11.055215    221.104302
# ...

# %% [markdown]
# ##handling missing vlaues ##

# %%
train_df.isnull().sum()
# Out:
# SubscriptionType            0
# PaymentMethod               0
# PaperlessBilling            0
# ContentType                 0
# MultiDeviceAccess           0
# DeviceRegistered            0
# GenrePreference             0
# Gender                      0
# ParentalControl             0
# SubtitlesEnabled            0
# AccountAge                  0
# MonthlyCharges              0
# TotalCharges                0
# ViewingHoursPerWeek         0
# AverageViewingDuration      0
# ContentDownloadsPerMonth    1
# UserRating                  1
# SupportTicketsPerMonth      1
# WatchlistSize               1
# CustomerID                  1
# Churn                       1
# dtype: int64

# %%
train_df=train_df.fillna(train_df.median())
# Out:
# <ipython-input-133-8fbbb42efcbb>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_df=train_df.fillna(train_df.median())

# %%
train_df.isnull().sum()
# Out:
# SubscriptionType            0
# PaymentMethod               0
# PaperlessBilling            0
# ContentType                 0
# MultiDeviceAccess           0
# DeviceRegistered            0
# GenrePreference             0
# Gender                      0
# ParentalControl             0
# SubtitlesEnabled            0
# AccountAge                  0
# MonthlyCharges              0
# TotalCharges                0
# ViewingHoursPerWeek         0
# AverageViewingDuration      0
# ContentDownloadsPerMonth    0
# UserRating                  0
# SupportTicketsPerMonth      0
# WatchlistSize               0
# CustomerID                  1
# Churn                       0
# dtype: int64

# %% [markdown]
# #now creating a model

# %%
train_df_s=train_df.drop('CustomerID', axis=1)
test_df_s=test_df.drop('CustomerID', axis=1)

# %%
#x_train=train_df_s.drop('Churn',axis=1)
#y_train=train_df_s['Churn']
# seperating the datas and labels
X=train_df_s.drop(columns = 'Churn', axis=1)
Y=train_df_s['Churn']

# %% [markdown]
# #standaridizing the data

# %%
from sklearn.preprocessing import StandardScaler

# Create an instance of StandardScaler
scaler = StandardScaler()

# Assuming you have a numpy array 'x' that you want to scale
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# %%
model= Sequential([
    Dense(20,activation='relu',name='l1',kernel_regularizer=tf.keras.regularizers.l2(0.1)
),
        Dense(15,activation='relu',name='l2',kernel_regularizer=tf.keras.regularizers.l2(0.1)
),
        Dense(1,activation='sigmoid',name='l3')
])

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 3096/3096 [==============================] - 7s 2ms/step - loss: 0.6235 - accuracy: 0.8166
# Epoch 2/10
# 3096/3096 [==============================] - 6s 2ms/step - loss: 0.4619 - accuracy: 0.8192
# Epoch 3/10
# 3096/3096 [==============================] - 6s 2ms/step - loss: 0.4500 - accuracy: 0.8192
# Epoch 4/10
# 3096/3096 [==============================] - 6s 2ms/step - loss: 0.4432 - accuracy: 0.8198
# Epoch 5/10
# 3096/3096 [==============================] - 6s 2ms/step - loss: 0.4396 - accuracy: 0.8219
# Epoch 6/10
# 3096/3096 [==============================] - 6s 2ms/step - loss: 0.4369 - accuracy: 0.8225
# Epoch 7/10
# 3096/3096 [==============================] - 6s 2ms/step - loss: 0.4351 - accuracy: 0.8230
# Epoch 8/10
# 3096/3096 [==============================] - 6s 2ms/step - loss: 0.4335 - accuracy: 0.8226
# Epoch 9/10
# 3096/3096 [==============================] - 6s 2ms/step - loss: 0.4322 - accuracy: 0.8227
# Epoch 10/10
# ...

# %%
# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(x_test, y_test)

# Print the evaluation results
print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# 775/775 [==============================] - 1s 1ms/step - loss: 0.4356 - accuracy: 0.8201
# Loss: 0.4356
# Accuracy: 0.8201

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
labels=label_encoder.fit_transform(train_df.SubscriptionType)
columns_to_encode=['SubscriptionType','PaymentMethod','PaperlessBilling','ContentType','MultiDeviceAccess','DeviceRegistered','GenrePreference','Gender','ParentalControl','SubtitlesEnabled']


from sklearn.compose import ColumnTransformer
ct = ColumnTransformer(
    transformers=[
        ('label_encoder',label_encoder, columns_to_encode)
    ],
    remainder='passthrough'
)


columns_data = train_df[columns_to_encode]
encoded_data = columns_data.apply(lambda x:label_encoder.fit_transform(x))
encoded_df = pd.concat([encoded_data, train_df.drop(columns_to_encode, axis=1)], axis=1)

columns_data = test_df[columns_to_encode]
encoded_data_test= columns_data.apply(lambda x:label_encoder.fit_transform(x))
encoded_df_test = pd.concat([encoded_data_test, test_df.drop(columns_to_encode, axis=1)], axis=1)

test_df=encoded_df_test
train_df=encoded_df

train_df=train_df.fillna(train_df.median())

train_df_s=train_df.drop('CustomerID', axis=1)
test_df_s=test_df.drop('CustomerID', axis=1)
X=train_df_s.drop(columns = 'Churn', axis=1)
Y=train_df_s['Churn']

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

model= Sequential([
    Dense(20,activation='relu',name='l1',kernel_regularizer=tf.keras.regularizers.l2(0.1)
),
        Dense(15,activation='relu',name='l2',kernel_regularizer=tf.keras.regularizers.l2(0.1)
),
        Dense(1,activation='sigmoid',name='l3')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10, batch_size=32)
