# %% [markdown]
# <a href="https://colab.research.google.com/github/SamridhiParihar/Machine-Learning-Projects/blob/main/multiclass_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1.1 Goals
# We will explore an example of multi-class classification using neural networks.
# <figure>
#  <img src="./images/C2_W2_mclass_header.png"   style="width500px;height:200px;">
# </figure>

# %%
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %% [markdown]
# # 2.0 Multi-class Classification
# Neural Networks are often used to classify data. Examples are neural networks:
# - take in photos and classify subjects in the photos as {dog,cat,horse,other}
# - take in a sentence and classify the 'parts of speech' of its elements: {noun, verb, adjective etc..}
#
# A network of this type will have multiple units in its final layer. Each output is associated with a category. When an input example is applied to the network, the output with the highest value is the category predicted. If the output is applied to a softmax function, the output of the softmax will provide probabilities of the input being in each category.
#
# In this lab you will see an example of building a multiclass network in Tensorflow. We will then take a look at how the neural network makes its predictions.
#
# Let's start by creating a four-class data set.

# %% [markdown]
# ## 2.1 Prepare and visualize our data
# We will use Scikit-Learn `make_blobs` function to make a training data set with 4 categories as shown in the plot below.

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# /content/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,

# %% [markdown]
# Each dot represents a training example. The axis (x0,x1) are the inputs and the color represents the class the example is associated with. Once trained, the model will be presented with a new example, (x0,x1), and will predict the class.
#
# While generated, this data set is representative of many real-world classification problems. There are several input features (x0,...,xn) and several output categories. The model is trained to use the input features to predict the correct output category.

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}")
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %%
tf.random.set_seed(1234) #produce reproducibility
model= Sequential(
    [
    Dense(2,activation='relu',name = "L1"),
    Dense(4,activation='linear',name = "L2")
    ]
    )

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X_train,y_train,
    epochs=200
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 5ms/step - loss: 1.9809
# Epoch 2/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8184
# Epoch 3/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6850
# Epoch 4/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5796
# Epoch 5/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4697
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3886
# Epoch 7/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3053
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2360
# Epoch 9/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1797
# Epoch 10/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1311
# Epoch 11/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0873
# Epoch 12/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0480
# Epoch 13/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0157
# Epoch 14/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9841
# Epoch 15/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9572
# Epoch 16/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9342
# Epoch 17/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9123
# Epoch 18/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8908
# Epoch 19/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8704
# Epoch 20/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8507
# Epoch 21/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8320
# Epoch 22/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8149
# Epoch 23/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7978
# Epoch 24/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7821
# Epoch 25/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7664
# Epoch 26/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7512
# Epoch 27/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7359
# Epoch 28/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7204
# Epoch 29/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7057
# Epoch 30/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6912
# Epoch 31/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6769
# Epoch 32/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6636
# Epoch 33/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6496
# Epoch 34/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6360
# Epoch 35/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6231
# Epoch 36/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6103
# Epoch 37/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5981
# Epoch 38/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5871
# Epoch 39/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5767
# Epoch 40/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5667
# Epoch 41/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5571
# Epoch 42/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5478
# Epoch 43/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5394
# Epoch 44/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5308
# Epoch 45/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5231
# Epoch 46/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5157
# Epoch 47/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5086
# Epoch 48/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5019
# Epoch 49/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4947
# Epoch 50/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4891
# Epoch 51/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4833
# Epoch 52/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4778
# Epoch 53/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4725
# Epoch 54/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4670
# Epoch 55/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4617
# Epoch 56/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4562
# Epoch 57/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4518
# Epoch 58/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4477
# Epoch 59/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4433
# Epoch 60/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4386
# Epoch 61/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4339
# Epoch 62/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4288
# Epoch 63/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4243
# Epoch 64/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4196
# Epoch 65/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4152
# Epoch 66/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4110
# Epoch 67/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4065
# Epoch 68/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4024
# Epoch 69/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3983
# Epoch 70/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3931
# Epoch 71/200

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 184/184 [==============================] - 0s 1ms/step

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1,b1 = l1.get_weights()

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes)
# Out:
# /content/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /content/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# /content/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /content/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /content/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /content/lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
